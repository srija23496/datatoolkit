# %%
#1 .Demonstrate three different methods for creating identical 2D arrays in NumPyƒ Provide the code for each
#method and the final output after each method

# %%
import numpy as np
import pandas as pd

# %%
#method 1
arr1 = np.array([[1,2,3],[4,5,6]])

# %%
#method 2
arr2 = np.ones((2,3)) * np.array([[1,2,3],[4,5,6]])

# %%
#method3
arr3 = np.full((2,3),0)
arr3[0,:] = [1,2,3]
arr3[1,:] = [4,5,6]

# %%
print(f"arr1 : {arr1}")
# Out:
# arr1 : [[1 2 3]
#  [4 5 6]]

# %%
print(f"arr2 : {arr2}")
# Out:
# arr2 : [[1. 2. 3.]
#  [4. 5. 6.]]

# %%
print(f"arr3 : {arr3}")
# Out:
# arr3 : [[1 2 3]
#  [4 5 6]]

# %%
#2 .Using the Numpy function, generate an array of 100 evenly spaced numbers between 1 and 10 and
# Reshape that 1D array into a 2D array
arr1 = np.linspace( 1, 10 ,100)
arr1.ndim  # It is a 1d array
# Out:
# 1

# %%
arr2 =arr1.reshape(2 , 50) # converted into 2d array
arr2.ndim  # shape changes into 2d array
# Out:
# 2

# %%
#3 . Explain the following terms:
#(i) The difference in np.array, np.asarray and np.asanyarray
#(ii) The difference between Deep copy and shallow copy
#(i) np.array create a new array object ,even if the input is already an array
# np.asarray covert anything into array irrespective of whether it is an array or not
# np.asanyarray covert only non array to an array
#(ii) shallow copy
#create a new object or array ,but only copies the reference to the original element
# Both the original element and copied element is same
# Deep copy
# Creates a new object or array and recursively copies all the element 
# copied data and original data is independent to eachm other
#4. Generate a 3x3 array with random floating-point numbers between 5 and 20 then, round each number in
#the array to 2 decimal places
random_array = np.random.uniform( 5 ,20 ,(3,3))
rounded_array = np.round(random_array , 2)
print(random_array)
# Out:
# [[15.17242638  9.04763644  9.6995177 ]
#  [ 9.1851849  13.78521872 11.28985925]
#  [13.85975178 16.33176689 13.57781144]]

# %%
print(rounded_array)
# Out:
# [[15.17  9.05  9.7 ]
#  [ 9.19 13.79 11.29]
#  [13.86 16.33 13.58]]

# %%
#5 .Create a NumPy array with random integers between 1 and 10 of shape (5,6) After creating the array
#perform the following operations:

 #a)Extract all even integers from array.

 #b)Extract all odd integers from array.
arr_1 = np.random.randint(1,10,(5,6))
arr1
# Out:
# array([ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#         1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182,
#         1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#         2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273,
#         2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#         3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364,
#         3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#         4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455,
#         4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#         5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545,
#         5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#         6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636,
#         6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
# ...

# %%
#(i)
even_array = arr_1[arr_1 % 2 == 0]

# %%
even_array
# Out:
# array([2, 8, 6, 6, 6, 6, 6, 6, 6, 4, 6, 4, 4])

# %%
odd_array = arr_1[arr_1 % 2 != 0]
odd_array
# Out:
# array([9, 3, 5, 9, 1, 7, 3, 5, 9, 5, 1, 1, 3, 7, 9, 5, 5])

# %%
#6. Create a 3D NumPy array of shape (3,3,3) containing random integers beween 1 and 10. Perform the
#following operations:

 #a) Find the indices of the maximum values along each depth level (third axis).

 #b) Perform element-wise multiplication of between both array
arr2 = np.random.randint(1,10 ,(3,3,3))
arr2
# Out:
# array([[[2, 7, 8],
#         [2, 9, 9],
#         [1, 5, 3]],
#
#        [[3, 3, 2],
#         [2, 8, 3],
#         [2, 5, 8]],
#
#        [[2, 1, 6],
#         [8, 3, 9],
#         [9, 9, 9]]])

# %%
#(i)
max_arr = np.argmax(arr2 , axis =2)
max_arr
# Out:
# array([[2, 1, 1],
#        [0, 1, 2],
#        [2, 2, 0]])

# %%
#(ii)
ele_product = np.multiply(arr2,max_arr)
ele_product
# Out:
# array([[[ 4,  7,  8],
#         [ 0,  9, 18],
#         [ 2, 10,  0]],
#
#        [[ 6,  3,  2],
#         [ 0,  8,  6],
#         [ 4, 10,  0]],
#
#        [[ 4,  1,  6],
#         [ 0,  3, 18],
#         [18, 18,  0]]])

# %%
#7. Clean and transform the 'Phone' column in the sample dataset to remove non-numeric characters and
#convert it to a numeric data type Also display the table attributes and data types of each column

# %%
data = pd.read_csv("People Data.csv")
data
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    27-01-2014
# 1    fergusonkatherine@example.net                    NaN    26-07-1931
# ...

# %%
[data["Phone"].fillna(0)]
# Out:
# [0               857.139.8239
#  1                          0
#  2              (599)782-0605
#  3                          0
#  4         (390)417-1635x3010
#                 ...
#  995             021.775.2933
#  996     001-149-710-7799x721
#  997    +1-750-774-4128x33265
#  998            (915)292-2254
#  999       079.752.5424x67259
#  Name: Phone, Length: 1000, dtype: object]

# %%
data["Phone"] = data["Phone"].fillna(0)
data
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    27-01-2014
# 1    fergusonkatherine@example.net                      0    26-07-1931
# ...

# %%
#8 . Perform the following tasks using people dataset:

# a) Read the 'data.csv' file using pandas, skipping the first 50 rows.

# b) Only read the columns: 'Last Name', ‘Gender’,’Email’,‘Phone’ and ‘Salary’ from the file.

# c) Display the first 10 rows of the filtered dataset.

# d) Extract the ‘Salary’' column as a Series and display its last 5 values
#(a)
data1 = pd.read_csv("People Data.csv", skiprows =50)
data1
# Out:
#        50  afF3018e9cdd1dA     George    Mercer  Female  \
# 0      51  CccE5DAb6E288e5         Jo    Zavala    Male
# 1      52  DfBDc3621D4bcec     Joshua     Carey  Female
# 2      53  f55b0A249f5E44D     Rickey     Hobbs  Female
# 3      54  Ed71DcfaBFd0beE      Robyn    Reilly    Male
# 4      55  FDaFD0c3f5387EC  Christina    Conrad    Male
# ..    ...              ...        ...       ...     ...
# 945   996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 946   997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 947   998  2adde51d8B8979E      Cathy  Mckinney  Female
# 948   999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 949  1000  8b756f6231DDC6e        Lee      Tran  Female
#
#     douglascontreras@example.net    +1-326-669-0118x4341  11-09-1941  \
# 0           pamela64@example.net  001-859-448-9935x54536  23-11-1992
# 1      dianashepherd@example.net    001-274-739-8470x814  07-01-1915
# 2      ingramtiffany@example.org        241.179.9509x498  01-07-1910
# ...

# %%
#(b)
data_new = data[['Gender',"Email","Phone","Salary"]]
data_new
# Out:
#      Gender                          Email                  Phone  Salary
# 0      Male            pwarner@example.org           857.139.8239   90000
# 1    Female  fergusonkatherine@example.net                      0   80000
# 2    Female            fhoward@example.org          (599)782-0605   50000
# 3      Male          zjohnston@example.com                      0   65000
# 4    Female               elin@example.net     (390)417-1635x3010  100000
# ..      ...                            ...                    ...     ...
# 995  Female         lyonsdaisy@example.net           021.775.2933   90000
# 996  Female        dariusbryan@example.com   001-149-710-7799x721   50000
# 997  Female         georgechan@example.org  +1-750-774-4128x33265   60000
# 998    Male            wanda04@example.net          (915)292-2254  100000
# 999  Female        deannablack@example.org     079.752.5424x67259   90000
#
# [1000 rows x 4 columns]

# %%
data_filtered = data_new.head(10)
data_filtered
# Out:
#    Gender                          Email               Phone  Salary
# 0    Male            pwarner@example.org        857.139.8239   90000
# 1  Female  fergusonkatherine@example.net                   0   80000
# 2  Female            fhoward@example.org       (599)782-0605   50000
# 3    Male          zjohnston@example.com                   0   65000
# 4  Female               elin@example.net  (390)417-1635x3010  100000
# 5    Male          kaitlin13@example.net          8537800927   50000
# 6    Male         jeffharvey@example.com   093.655.7480x7895   60000
# 7    Male           alicia33@example.org          4709522945   65000
# 8    Male             jake50@example.com        013.820.4758   50000
# 9    Male      lanechristina@example.net  (560)903-5068x4985   50000

# %%
data_salary = data["Salary"].tail(5)
data_new1 = pd.DataFrame(data_salary)
data_new1
# Out:
#      Salary
# 995   90000
# 996   50000
# 997   60000
# 998  100000
# 999   90000

# %%
#9 . Filter and select rows from the People_Dataset, where the “Last Name' column contains the name 'Duke', 
#'Gender' column contains the word Female and ‘salary’ should be less than 85000
filtered_data = data[(data["Last Name"] == "Duke") & (data["Gender"] == "Female") & (data["Salary"] <85000)] 
filtered_data
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 45      46  99A502C175C4EBd     Olivia      Duke  Female
# 210    211  DF17975CC0a0373    Katrina      Duke  Female
# 457    458  dcE1B7DE83c1076      Traci      Duke  Female
# 729    730  c9b482D7aa3e682     Lonnie      Duke  Female
#
#                         Email                   Phone Date of birth  \
# 45        diana26@example.net  001-366-475-8607x04350    13-10-1934
# 210       robin78@example.com            740.434.0212    21-09-1935
# 457  perryhoffman@example.org     +1-903-596-0995x489    11-02-1997
# 729   kevinkramer@example.net            982.692.6257    12-05-2015
#
#            Job Title  Salary
# 45           Dentist   60000
# 210  Producer, radio   50000
# 457        Herbalist   50000
# 729     Nurse, adult   70000

# %%
#10 . Create a 7*5 Dataframe in Pandas using a series generated from 35 random integers between 1 to 6
random_series = np.random.randint( 1 , 6 , (7,5))
random_series
# Out:
# array([[2, 1, 4, 5, 5],
#        [4, 3, 2, 5, 2],
#        [5, 4, 4, 2, 5],
#        [2, 1, 5, 5, 1],
#        [3, 5, 2, 1, 1],
#        [2, 4, 2, 2, 4],
#        [1, 2, 1, 3, 3]])

# %%
df_random_series = pd.DataFrame(random_series)
df_random_series
# Out:
#    0  1  2  3  4
# 0  2  1  4  5  5
# 1  4  3  2  5  2
# 2  5  4  4  2  5
# 3  2  1  5  5  1
# 4  3  5  2  1  1
# 5  2  4  2  2  4
# 6  1  2  1  3  3

# %%
#11 . Create two different Series, each of length 50, with the following criteria:

#a) The first Series should contain random numbers ranging from 10 to 50.

#b) The second Series should contain random numbers ranging from 100 to 1000.

#c) Create a DataFrame by 'joining these Series by column, and, change the names of the columns to 'col1', 'col2',
#etc
series1 = np.random.randint( 10 ,50 , 50 )
sr1 = pd.DataFrame(series1)
series2 = np.random.randint( 100 , 1000 , 50)
sr2 = pd.DataFrame(series2)
final_series = pd.concat([sr1 , sr2], axis =1)
final_series
final_series.columns = ['cols1','cols2']
final_series
# Out:
#     cols1  cols2
# 0      27    905
# 1      39    653
# 2      45    573
# 3      43    632
# 4      28    242
# 5      38    796
# 6      42    208
# 7      16    556
# 8      35    904
# 9      40    466
# 10     39    554
# 11     12    266
# 12     30    611
# 13     39    804
# 14     35    969
# 15     15    379
# 16     45    413
# 17     22    251
# 18     16    724
# 19     33    339
# 20     25    997
# 21     35    631
# 22     22    637
# 23     19    975
# 24     27    384
# 25     31    658
# 26     35    129
# 27     19    532
# 28     30    856
# 29     25    380
# 30     34    199
# 31     41    286
# 32     43    799
# 33     11    438
# 34     45    754
# 35     49    636
# 36     26    427
# 37     46    312
# 38     17    649
# 39     15    943
# 40     42    287
# 41     28    271
# 42     39    446
# 43     48    474
# 44     23    106
# 45     26    189
# 46     22    307
# 47     37    205
# 48     33    609
# 49     40    685

# %%
#12. Perform the following operations using people data set:

#a) Delete the 'Email', 'Phone', and 'Date of birth' columns from the dataset.

#b) Delete the rows containing any missing values.

#c) Print the final output also&
#(a)
data.drop(["Email","Phone","Date of birth"],axis = 1 , inplace =True)
data
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                            Job Title  Salary
# 0                  Probation officer   90000
# 1                             Dancer   80000
# 2                               Copy   50000
# 3           Counselling psychologist   65000
# 4                Biomedical engineer  100000
# ...

# %%
data.dropna()
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                            Job Title  Salary
# 0                  Probation officer   90000
# 1                             Dancer   80000
# 2                               Copy   50000
# 3           Counselling psychologist   65000
# 4                Biomedical engineer  100000
# ...

# %%
data.isna().sum()  # Drop every colum and rows which cointain nan value
# Out:
# Index         0
# User Id       0
# First Name    0
# Last Name     0
# Gender        0
# Job Title     0
# Salary        0
# dtype: int64

# %%
#13. Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the
#following tasks using Matplotlib and NumPy:

#a) Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'.

#b) Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.

#c) Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.

#d) Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'.

#e) Set the title of the plot as 'Advanced Scatter Plot of Random Values'.

#f) Display a legend for the scatter plot, the horizontal line, and the vertical lin
x = np.random.rand(100)
y = np.random.rand(100)

# %%
#(a)
import matplotlib.pyplot as plt
plt.scatter( x , y , color = 'red' , marker = 'o')
#(b)
plt.axhline( y = 0.5 , color = 'black' , linestyle ='--' , label = 'y = 0.5')
#(c)
plt.axvline( x = 0.5 , color = 'black' , linestyle =':' , label = 'y = 0.5')
#(d)
plt.xlabel("X-axis")
plt.ylabel("y_axis")
plt.title("scatter plot with random values ")
plt.legend()
plt.show()

# %%
#14 . Create a time-series dataset in a Pandas DataFrame with columns: 'Date', 'Temperature', 'Humidity' and
#Perform the following tasks using Matplotlib:
#a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes (left y-axis for 'Temperature' and
#right y-axis for 'Humidity').

#b) Label the x-axis as 'Date'.

#c) Set the title of the plot as 'Temperature and Humidity Over Time

# %%
# creating a time series
date = pd.date_range(start = "2024-07-23" , end = "2024-08-22")
temprature = np.random.rand(31)*20 + 10
humidity = np.random.rand(31)*50 + 30

# %%
data = pd.DataFrame({'Date':date , 'Temprature':temprature , "Humidity":humidity})
data
# Out:
#          Date  Temprature   Humidity
# 0  2024-07-23   29.931628  59.481080
# 1  2024-07-24   24.573869  56.285157
# 2  2024-07-25   12.123651  75.818547
# 3  2024-07-26   11.355889  71.145974
# 4  2024-07-27   19.900906  40.984072
# 5  2024-07-28   27.513413  60.205096
# 6  2024-07-29   21.441515  61.578026
# 7  2024-07-30   26.622299  61.079070
# 8  2024-07-31   12.239255  63.725121
# 9  2024-08-01   14.785238  69.388060
# 10 2024-08-02   15.912250  54.008153
# 11 2024-08-03   10.284644  45.953549
# 12 2024-08-04   10.753833  48.027702
# 13 2024-08-05   26.857781  40.737230
# 14 2024-08-06   13.799969  54.967412
# 15 2024-08-07   17.408648  77.870180
# 16 2024-08-08   13.474726  72.117373
# 17 2024-08-09   18.463263  37.899622
# 18 2024-08-10   13.213874  34.692029
# 19 2024-08-11   18.905494  61.825039
# 20 2024-08-12   17.048956  63.004836
# 21 2024-08-13   12.962866  77.924526
# 22 2024-08-14   25.460050  63.817987
# 23 2024-08-15   27.869600  57.711939
# ...

# %%
#(a)
ax1 = plt.subplot()
ax1.plot(data["Date"],data["Temprature"],color='red')
ax1.set_xlabel("Date")
ax1.set_ylabel("Temprature",color = 'red')
ax1.tick_params(axis ='y' , labelcolor='red')

ax2 = ax1.twinx()
ax2.plot(data["Date"],data["Humidity"],color = 'blue')
ax2.set_ylabel('Humidity',labelcolor='blue')
ax2.tick_params(axis='y',labelcolor='blue')

plt.title('Temprature and Humidity Over Time')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 10
#       8 ax2 = ax1.twinx()
#       9 ax2.plot(data["Date"],data["Humidity"],color = 'blue')
# ---> 10 ax2.set_ylabel('Humidity',labelcolor='blue')
#      11 ax2.tick_params(axis='y',labelcolor='blue')
#      13 plt.title('Temprature and Humidity Over Time')
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/axes/_base.py:3762, in _AxesBase.set_ylabel(self, ylabel, fontdict, labelpad, loc, **kwargs)
#    3755     y, ha = {
#    3756         'bottom': (0, 'left'),
#    3757         'center': (0.5, 'center'),
#    3758         'top': (1, 'right')
#    3759     }[loc]
#    3760     kwargs.update(y=y, horizontalalignment=ha)
# -> 3762 return self.yaxis.set_label_text(ylabel, fontdict, **kwargs)
#
# ...

# %%
#15. Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following
# tasks using Matplotlib:
#a) Plot a histogram of the data with 30 bins.

#b) Overlay a line plot representing the normal distribution's probability density function (PDF).

#c) Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'.

#d) Set the title of the plot as 'Histogram with PDF Overlay'.

# %%
from scipy.stats import norm
data = np.random.normal(loc=0 , scale = 1 , size =1000)
#(a)
plt.hist(data, bins = 30 , density = True , alpha = 0.5 , label = "Histogram")

#(b)
x = np.linspace(-3 , 3 , 100)
plt.plot(x , norm.pdf(x , loc = 0 , scale = 1) , 'r-',label = 'Normal Distribution PDF')

plt.xlabel('Value')
plt.ylabel('Frequency/Probabilty')
plt.title('Histogram with PDF with PDF overlay')
plt.legend
plt.show()

# %%
#16. Set the title of the plot as 'Histogram with PDF Overlay'.
# DONE IN THE PREVIOUS QUESTION

# %%
#17. Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the
#origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot'.

# %%
import seaborn as sns
np.random.seed(0)
x = np.random.randn(100)
y = np.random.randn(100)

df = pd.DataFrame({'x': x, 'y': y})

def classify_quadrant(row):
    if row['x'] >= 0 and row['y'] >= 0:
        return 'Quadrant I'
    elif row['x'] < 0 and row['y'] >= 0:
        return 'Quadrant II'
    elif row['x'] < 0 and row['y'] < 0:
        return 'Quadrant III'
    else:
        return 'Quadrant IV'

df['Quadrant'] = df.apply(classify_quadrant, axis=1)

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='x', y='y', hue='Quadrant', palette='viridis')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Quadrant-wise Scatter Plot')
plt.legend(title='Quadrants')

plt.show()

# %%
#18. With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine
#Wave Function'

# %%
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Sine Wave')
plt.grid(True)

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave Function')
plt.legend()
plt.show()

# %%
#19 Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their
# values, add hover tooltips to display exact values, label the axes, and set the title as 'Random Cateorical
# Bar Chart

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool

# %%
output_notebook()

np.random.seed(0)
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(1, 10, size=len(categories))

df = pd.DataFrame({'Category': categories, 'Value': values})

source = ColumnDataSource(df)

from bokeh.transform import linear_cmap
from bokeh.palettes import Viridis256
color_mapper = linear_cmap(field_name='Value', palette=Viridis256, low=min(values), high=max(values))

p = figure(x_range=df['Category'],title='Random Categorical Bar Chart',
           toolbar_location=None, tools="")

p.vbar(x='Category', top='Value', width=0.4, source=source, color=color_mapper, legend_field='Value')

hover = HoverTool()
hover.tooltips = [("Category", "@Category"), ("Value", "@Value")]
p.add_tools(hover)

p.xaxis.axis_label = 'Category'
p.yaxis.axis_label = 'Value'
p.xaxis.major_label_orientation = "vertical"

p.legend.title = 'Value'
p.legend.orientation = "horizontal"

show(p)
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>
#   <div id="a2088c03-90f8-4d80-8836-c96d6a8dc9b9" data-root-id="p1006" style="display: contents;"></div>

# %%
#20.  Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as
#'Simple Line Plot

# %%
import plotly.graph_objects as go

np.random.seed(0)
x = np.linspace(0, 10, 100)
y = np.random.randn(100)

fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=y, mode='lines', name='Random Data'))

fig.update_layout(
    title='Simple Line Plot',
    xaxis_title='X-axis',
    yaxis_title='Y-axis'
)
    
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 import plotly.graph_objects as go
#       3 np.random.seed(0)
#       4 x = np.linspace(0, 10, 100)
#
# ModuleNotFoundError: No module named 'plotly'

# %%
#21. Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set
# the title as 'Interactive Pie Chart'.

# %%
import plotly.graph_objects as go

np.random.seed(0)
labels = ['Category A', 'Category B', 'Category C', 'Category D']
values = np.random.randint(10, 50, size=len(labels))
fig = go.Figure(data=[go.Pie(labels=labels, values=values, 
                             textinfo='label+percent', 
                             hole=0.3)])
fig.update_layout(title='Interactive Pie Chart')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 import plotly.graph_objects as go
#       3 np.random.seed(0)
#       4 labels = ['Category A', 'Category B', 'Category C', 'Category D']
#
# ModuleNotFoundError: No module named 'plotly'
